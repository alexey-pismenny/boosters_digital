# %%
import pandas as pd
import numpy as np

# %%
x3 = pd.read_csv('X3.csv')
X_train = x3[[str(i) for i in range(1, 453)]].to_numpy()

# %%
x3_test = pd.read_csv('X3_test.csv')
X_test = x3_test[[str(i) for i in range(1, 453)]].to_numpy()

# %%
y_csv = pd.read_csv('Y.csv')
Y_5 = y_csv[[str(i) for i in range(1, 6)]].to_numpy()

# %%
Y_5.shape
# Out:
# (4000, 5)

# %%
#for i in range(X_train.shape[0]):
#    X_train[i,:] /= (np.sqrt(X_train[i,:] ** 2) + 1e-8)
    
#for i in range(X_train.shape[1]):
#    X_train[:,i] /= (np.sqrt(np.sum(X_train[:,i] ** 2)) + 1e-8)

# %%
#for i in range(X_test.shape[0]):
#    X_test[i,:] /= (np.sqrt(X_test[i,:] ** 2) + 1e-8)
    
#for i in range(X_test.shape[1]):
#    X_test[:,i] /= (np.sqrt(np.sum(X_test[:,i] ** 2)) + 1e-8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(X_train, Y_5[:,4])
res = model.predict(X_test)[:,1]
# Out:
# /home/alex/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
d = {}

# %%
d['5'] = res.tolist()

# %%
len(d['1'])
# Out:
# 4058

# %%
d['id'] = x3_test['id']

# %%
# Out:
# {'1': [0.28895197320632676,
#   0.30265799445767577,
#   0.2529846506404382,
#   0.3156017383724608,
#   0.3111796118330698,
#   0.25509268892332737,
#   0.3165958762281938,
#   0.30556528460707666,
#   0.3061525202049173,
#   0.31599630247795607,
#   0.30036146207637915,
#   0.30733587051452826,
#   0.33566481676965315,
#   0.27957675457026815,
#   0.3044920533296382,
#   0.3286471363104766,
#   0.28492333470092557,
#   0.30979199535762136,
#   0.31116157585416376,
#   0.31310011425023937,
#   0.4165483849225782,
#   0.30358918024549186,
#   0.2912315277317455,
#   0.31343136470577787,
#   0.3180924340961071,
#   0.3092630118352432,
#   0.29661168559811885,
#   0.2986906648955077,
#   0.3188609835867918,
#   0.2888652133996154,
#   0.3885257012876442,
#   0.28910088329533745,
#   0.28471179992431705,
#   0.29442688776697473,
#   0.27909569885486374,
#   0.3402838423059007,
#   0.2984562364798796,
#   0.29147384616907157,
#   0.3029530216000921,
#   0.310763419121767,
# ...

# %%
df = pd.DataFrame(data=d)
df = df[['id', '1', '2', '3', '4', '5']]

# %%
with open('reg.csv', 'w') as f:
    df.to_csv(f, index=False)
