# %%
import pandas as pd
import numpy as np

# %%
x2_pd = pd.read_csv('X2.csv')
y_pd = pd.read_csv('Y.csv')

# %%
x2_pd
# Out:
#           id       A
# 0          3       5
# 1          3   70340
# 2          3   72868
# 3          3   73471
# 4          3   74998
# ...      ...     ...
# 462883  8056  142893
# 462884  8056  142687
# 462885  8056  139577
# 462886  8056  128067
# 462887  8056  213997
#
# [462888 rows x 2 columns]

# %%
d = {}
for i in range(len(x2_pd)):
    if x2_pd['A'][i] in d:
        d[x2_pd['A'][i]]
